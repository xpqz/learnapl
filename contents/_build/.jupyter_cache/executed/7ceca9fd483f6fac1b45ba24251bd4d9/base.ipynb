# %%
]load HttpCommand
# Out:
# <span style="white-space:pre; font-family: monospace">done
#
# Rebuilding user command cache... done
# </span>
# <span style="white-space:pre; font-family: monospace">#.HttpCommand
# </span>

# %%
date←'2018-06-15'
url←'https://api.nasa.gov/neo/rest/v1/feed'
API_KEY←'EyhTU05K3xSkwAGPVoBbDp7RPzdT2YwhCRP6XBaa'
      
(params←⎕NS'').(start_date end_date api_key)←date date API_KEY
⎕←z←HttpCommand.Get url params
{(⍵[;1]∊⊂'Content-Type')⌿⍵}z.Headers
j←⎕JSON z.Data
# Out:
# <span style="white-space:pre; font-family: monospace">[rc: 0 | msg: "" | HTTP Status: 200 "" | ⍴Data: 9811]
# </span>
# <span style="white-space:pre; font-family: monospace">┌────────────┬──────────────────────────────┐
# │Content-Type│application/json;charset=UTF-8│
# └────────────┴──────────────────────────────┘
# </span>

# %%
base_url←'https://skruger.cloudant.com/airaccidents/_all_docs'
(params←⎕NS'').(include_docs limit)←'true' 5

# %%
⎕←z←HttpCommand.Get base_url params
# Out:
# <span style="white-space:pre; font-family: monospace">[rc: 0 | msg: "" | HTTP Status: 200 "OK" | ⍴Data: 5309]
# </span>

# %%
⍝j←⎕JSON z.Data
j←(⎕JSON⍠'M')z.Data

# %%
j.rows
# Out:
# SYNTAX ERROR
#       j.rows
#       ∧

# %%
j.rows[1].doc._id
# Out:
# SYNTAX ERROR
#       j.rows[1].doc._id
#       ∧

# %%
]map j.rows[1].doc
# Out:
# <span style="white-space:pre; font-family: monospace">Usage: ]Map [namespace]
# </span>

# %%
j
# Out:
# <span style="white-space:pre; font-family: monospace">┌─┬──────────────────────┬──────────────────────────────────┬─┐
# │0│                      │                                  │1│
# ├─┼──────────────────────┼──────────────────────────────────┼─┤
# │1│total_rows            │68389                             │3│
# ├─┼──────────────────────┼──────────────────────────────────┼─┤
# │1│offset                │0                                 │3│
# ├─┼──────────────────────┼──────────────────────────────────┼─┤
# │1│rows                  │                                  │2│
# ├─┼──────────────────────┼──────────────────────────────────┼─┤
# │2│                      │                                  │1│
# ├─┼──────────────────────┼──────────────────────────────────┼─┤
# │3│id                    │42788bb50806d9cc7770d46953000c99  │4│
# ├─┼──────────────────────┼──────────────────────────────────┼─┤
# │3│key                   │42788bb50806d9cc7770d46953000c99  │4│
# ...
